# %%
tmrw="April 23 2020"
today="April 22 2020"

#=========================#
# USA
#Actuals
Cases_Usa_A=int(848735)
Deaths_Usa_A=int(47663)

# CANADA 
#Actuals
Cases_Canada_A=int(40190)
Deaths_Canada_A=int(2074)

#ONTARIO
#Actuals
Ontario_Cases_A=int(12245)

#=======================#
#USA
#Projections
Cases_Usa_P=int(878967)
Deaths_Usa_P=int(48343)

#CANADA
#Projections
Cases_Canada_P=int(42463)
Deaths_Canada_P=int(2123)

#ONTARIO
#Projections
Ontario_Cases_P=int(12873)
    
#=========================#
diff_cases_USA=Cases_Usa_P-Cases_Usa_A
diff_deaths_USA=Deaths_Usa_P-Deaths_Usa_A
diff_Canada_cases= Cases_Canada_P-Cases_Canada_A
diff_Canada_deaths= Deaths_Canada_P - Deaths_Canada_A
diff_Ontario_cases = Ontario_Cases_P-Ontario_Cases_A
    
print("Projections for", tmrw)
print("\n")
print("USA:", ('{:,}'.format(Cases_Usa_P)), "cases &", ('{:,}'.format(Deaths_Usa_P)), "dead" )
print("+",('{:,}'.format(diff_cases_USA)), "cases |", "+",diff_deaths_USA, "dead")
print("\n")
print("Canada:", ('{:,}'.format(Cases_Canada_P)), "&", ('{:,}'.format(Deaths_Canada_P)) )
print("+", ('{:,}'.format(diff_Canada_cases)), "cases |", "+", ('{:,}'.format(diff_Canada_deaths)), "dead")
print("\n")
print("Ontario:",('{:,}'.format(Ontario_Cases_P)))
print("+", ('{:,}'.format(diff_Ontario_cases)), "cases")
print("\n")

print("#COVID19 #coronavirus #CoronavirusPandemic #CoronavirusUSA")
print("\n")
print("===============================")
print("\n")
print("UPDATED ACTUAL FOR",today.upper())
print("\n")
print ("USA:",('{:,}'.format(Cases_Usa_A)),"cases &",('{:,}'.format(Deaths_Usa_A)),"dead")
print("\n")
print("Canada:",('{:,}'.format(Cases_Canada_A)),"cases &",('{:,}'.format(Deaths_Canada_A)),"dead")
print("\n")
print("Ontario:",('{:,}'.format(Ontario_Cases_A)),"cases")
# Out:
# Projections for April 23 2020
#
#
# USA: 878,967 cases & 48,343 dead
# + 30,232 cases | + 680 dead
#
#
# Canada: 42,463 & 2,123
# + 2,273 cases | + 49 dead
#
#
# Ontario: 12,873
# + 628 cases
#
#
# #COVID19 #coronavirus #CoronavirusPandemic #CoronavirusUSA
#
#
# ...
#
#
# UPDATED ACTUAL FOR APRIL 22 2020
#
#
# USA: 848,735 cases & 47,663 dead
#
#
# Canada: 40,190 cases & 2,074 dead
#
#
# Ontario: 12,245 cases
